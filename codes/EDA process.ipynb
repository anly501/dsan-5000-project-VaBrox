# %%
## import necessary libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import numpy as np

# %%
## read dataset needed for this project
## reason the following datasets been choosen is that the main purpose of this project is to find the relationship between pit stop time and 
## drivers with constructors. Therefore, dataset like qualifying and sprint race are deserted since they have no obvious relation with the 
## purpose of this project.
drivers = pd.read_csv('Data/drivers.csv')
pitStops = pd.read_csv('Data/pit_stops.csv')
constructors = pd.read_csv('Data/constructors.csv')
races = pd.read_csv('Data/races.csv')
circuits = pd.read_csv('Data/circuits.csv')
results = pd.read_csv('Data/results.csv')

# %% [markdown]
# # Check the drivers dataset:

# %%
drivers.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
## check how many \N are there in the column number since not all drivers had a number in the race
num_null = (drivers['number'] == r'\N').sum()
num_null
# Out:
# 803

# %%
drivers['driverName'] = drivers['forename'] + ' ' + drivers['surname']
drivers = drivers.rename(columns = {'nationality' : 'driverNationality'})

# %%
## we can drop unrelated variables since they obviously will not influence the data analysis
drivers = drivers.drop(labels = ['driverRef', 'number', 'code','forename', 'surname', 'dob', 'url'], axis = 1)

# %% [markdown]
# # Check the pitStops dataset:

# %%
pitStops.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
## here we can get the statistical information about the pitStops dataset
pitStops.describe().T
# Out:
#                 count          mean            std      min      25%      50%  \
# raceId        10089.0    962.774011      81.144375    841.0    888.0    958.0
# driverId      10089.0    523.998910     389.698555      1.0     18.0    815.0
# stop          10089.0      1.759738       0.916282      1.0      1.0      2.0
# lap           10089.0     25.312023      14.729775      1.0     13.0     25.0
# milliseconds  10089.0  75348.633363  278858.845817  12897.0  21914.0  23570.0
#
#                   75%        max
# raceId         1035.0     1110.0
# driverId        831.0      858.0
# stop              2.0        6.0
# lap              36.0       78.0
# milliseconds  26202.0  3069017.0

# %%
pitStops = pitStops.rename(columns = {'time' : 'pitTime'})
pitStops['seconds'] = pitStops['milliseconds'].apply(lambda x: x/1000)

# %%
pitStops = pitStops.drop(labels = ['milliseconds'], axis = 1)

# %% [markdown]
# # Checking the constructors dataset:

# %%
constructors.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
## we also need to drop an unnecessary column here which is the url column
constructors = constructors.drop(labels = ['url'], axis = 1)

# %%
constructors = constructors.rename(columns={'name' : 'constructorName', 'nationality' : 'constructorNationality'})

# %% [markdown]
# # Checking the races dataset:

# %%
races.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# 0       \N       \N       \N       \N       \N         \N         \N
# 1       \N       \N       \N       \N       \N         \N         \N
# 2       \N       \N       \N       \N       \N         \N         \N
# 3       \N       \N       \N       \N       \N         \N         \N
# 4       \N       \N       \N       \N       \N         \N         \N
#
#   sprint_date sprint_time
# 0          \N          \N
# 1          \N          \N
# 2          \N          \N
# 3          \N          \N
# 4          \N          \N

# %%
## check the ratio of \N in the fp and quali columns since we can observe huge amount of \N  
valueCheck = '\\N'
total = len(races)
value = races[races[['fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time', 'quali_date', 'quali_time', 'sprint_date', 'sprint_time']].isin([valueCheck]).any(axis=1)].shape[0]
ratio = value / total
print('Ratio is:', ratio)
# Out:
# Ratio is: 1.0

# %%
# since the ratio of \N in those columns is 1, therefore, we can drop those columns snice they will not affect the analysis
races = races.drop(labels = ['fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time', 'quali_date', 'quali_time', 'sprint_date', 'sprint_time', 'url'], axis = 1)

# %%
races = races.rename(columns = {'name' : 'raceName'})

# %% [markdown]
# # Check the circuits dataset

# %%
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt  \
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park

# %%
circuits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   circuitId   77 non-null     int64
#  1   circuitRef  77 non-null     object
#  2   name        77 non-null     object
#  3   location    77 non-null     object
#  4   country     77 non-null     object
#  5   lat         77 non-null     float64
#  6   lng         77 non-null     float64
#  7   alt         77 non-null     object
#  8   url         77 non-null     object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 5.5+ KB

# %%
## we still gonna drop the column url since it will not affect our analysis
circuits = circuits.drop(labels = ['url'], axis = 1)

# %%
circuits = circuits.rename(columns = {'name' : 'circuitName', 'location' : 'circuitLocation', 'country' : 'circuitCountry'})

# %%
## infomation provided by the circuits dataset that can be used in the analysis is the circuitid and name which we will compare the relationship 
## between pit stop time and each circuit.
## however, we can see that the dataset also provided us with the latitude, longtitude, and altitude of each circuits, we can plot the circuits map
## to make people who does not familiar with F1 race have a better understanding of it.
import folium
coordinates = []
for lat, lng in zip(circuits['lat'], circuits['lng']):
    coordinates.append([lat, lng])
maps = folium.Map(zoom_start = 2, title = 'Stamen Watercolor')
for i, j in zip(coordinates, circuits.circuitName):
    marker = folium.Marker(
        location = i,
        icon = folium.Icon(icon = "car", color = 'green', prefix = 'fa'),
        popup = "<strong>{0}</strong>".format(j))
    marker.add_to(maps)
maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25afcc94fcacc13f7f8e4b58d7c8dbdd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25afcc94fcacc13f7f8e4b58d7c8dbdd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25afcc94fcacc13f7f8e4b58d7c8dbdd = L.map(
#                 &quot;map_25afcc94fcacc13f7f8e4b58d7c8dbdd&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Stamen Watercolor&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e41c5d78c3fa669cf7142f4efb75a00 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_25afcc94fcacc13f7f8e4b58d7c8dbdd);
#
#
#             var marker_0a367fc5b4df375be11633a3cb55f2e7 = L.marker(
#                 [-37.8497, 144.968],
#                 {}
#             ).addTo(map_25afcc94fcacc13f7f8e4b58d7c8dbdd);
#
#
#             var icon_b600f9a2b0c48e6c20d90eca6752b964 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0a367fc5b4df375be11633a3cb55f2e7.setIcon(icon_b600f9a2b0c48e6c20d90eca6752b964);
#
#
#         var popup_85453211ba19f8b8e743fe479554b966 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_086116284f42d7b68209f8c7efc9c8b7 = $(`&lt;div id=&quot;html_086116284f42d7b68209f8c7efc9c8b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Albert Park Grand Prix Circuit&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_85453211ba19f8b8e743fe479554b966.setContent(html_086116284f42d7b68209f8c7efc9c8b7);
#
#
#
#         marker_0a367fc5b4df375be11633a3cb55f2e7.bindPopup(popup_85453211ba19f8b8e743fe479554b966)
#         ;
#
#
#
#
#             var marker_c4a1c4557a247531773f3973be141993 = L.marker(
#                 [2.76083, 101.738],
#                 {}
#             ).addTo(map_25afcc94fcacc13f7f8e4b58d7c8dbdd);
#
#
#             var icon_c0723d0769e3709006ea00d705d74016 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c4a1c4557a247531773f3973be141993.setIcon(icon_c0723d0769e3709006ea00d705d74016);
#
#
#         var popup_a975b200ff76b0fd4c726f6afd53d138 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7f1e2f9a60e6947a959a2006cc7bec6 = $(`&lt;div id=&quot;html_a7f1e2f9a60e6947a959a2006cc7bec6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Sepang International Circuit&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_a975b200ff76b0fd4c726f6afd53d138.setContent(html_a7f1e2f9a60e6947a959a2006cc7bec6);
#
#
#
#         marker_c4a1c4557a247531773f3973be141993.bindPopup(popup_a975b200ff76b0fd4c726f6afd53d138)
#         ;
#
#
#
#
#             var marker_f6fc201ff65199aff009b7585488c5da = L.marker(
#                 [26.0325, 50.5106],
#                 {}
#             ).addTo(map_25afcc94fcacc13f7f8e4b58d7c8dbdd);
#
#
#             var icon_2a95d0c42dbab51817574403caa6321b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;car&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f6fc201ff65199aff009b7585488c5da.setIcon(icon_2a95d0c42dbab51817574403caa6321b);
#
#
#         var popup_034d7735b56d3c19d756f787f1e2ea59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44081ffdf13478f8cdf3338a1be3133b = $(`&lt;div id=&quot;html_44081ffdf13478f8cdf3338a1be3133b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Bahrain International Circuit&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_034d7735b56d3c19d756f787f1e2ea59.setContent(html_44081ffdf13478f8cdf3338a1be3133b);
#
#
#
#         marker_f6fc201ff65199aff009b7585488c5da.bindPopup(popup_034d7735b56d3c19d756f787f1e2ea59)
#         ;
#
#
#
#
#             var marker_93a9ca43926b3da84da5e5cd69dd0e3a = L.marker(
#                 [41.57, 2.26111],
#                 {}
#             ).addTo(map_25afcc94fcacc13f7f8e4b58d7c8dbdd);
#
#
#             var icon_799ae0093683cdc2daae79993b103

# %% [markdown]
# # Check the results dataset

# %%
results.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time fastestLap rank  \
# 0            1              1    10.0    58  1:34:50.616         39    2
# 1            2              2     8.0    58       +5.478         41    3
# 2            3              3     6.0    58       +8.163         41    5
# 3            4              4     5.0    58      +17.181         58    7
# 4            5              5     4.0    58      +18.014         43    1
#
#   fastestLapTime fastestLapSpeed  statusId  fastestLapTime_seconds
# 0       1:27.452         218.300         1                  87.452
# 1       1:27.739         217.586         1                  87.739
# 2       1:28.090         216.719         1                  88.090
# 3       1:28.603         215.464         1                  88.603
# 4       1:27.418         218.385         1                  87.418

# %%
results.describe().T
# Out:
#                  count          mean          std  min      25%      50%  \
# resultId       26080.0  13041.372661  7530.008377  1.0  6520.75  13040.5
# raceId         26080.0    536.695667   303.034639  1.0   294.75    519.0
# driverId       26080.0    266.277569   272.581622  1.0    57.00    163.0
# constructorId  26080.0     49.059663    60.221056  1.0     6.00     25.0
# grid           26080.0     11.167561     7.232797  0.0     5.00     11.0
# positionOrder  26080.0     12.854141     7.700068  1.0     6.00     12.0
# points         26080.0      1.906635     4.219715  0.0     0.00      0.0
# laps           26080.0     46.076687    29.726058  0.0    22.00     53.0
# statusId       26080.0     17.476074    26.129965  1.0     1.00     10.0
#
#                     75%      max
# resultId       19560.25  26085.0
# raceId           791.00   1110.0
# driverId         364.00    858.0
# constructorId     58.25    214.0
# grid              17.00     34.0
# positionOrder     18.00     39.0
# points             2.00     50.0
# laps              66.00    200.0
# statusId          14.00    141.0

# %%
results = results.drop(labels = ['milliseconds'], axis = 1)

# %%
results['position'] = results['position'].replace(r'\\N', np.nan, regex = True)
results = results.dropna(subset = ['position'])

# %%
def convert_to_seconds(time_str):
    try:
        minutes, rest = time_str.split(":")
        seconds, milliseconds = rest.split(".")
        total_seconds = int(minutes)*60 + int(seconds) + int(milliseconds)/1000
        return total_seconds
    except ValueError:
        return None

# Apply the function to the column
results['fastestLapTime_seconds'] = results['fastestLapTime'].apply(convert_to_seconds)
results = results.dropna(subset = ['fastestLapSpeed'])
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26073     26079    1110       848              3     23    15       14
# 26074     26080    1110       825            210     20    16       15
# 26075     26081    1110       817            213      3    19       16
# 26076     26082    1110       858              3      2    18       17
# 26077     26083    1110       807            210     27     0       18
#
#       positionText  positionOrder  points  laps         time fastestLap rank  \
# 0                1              1    10.0    58  1:34:50.616         39    2
# 1                2              2     8.0    58       +5.478         41    3
# 2                3              3     6.0    58       +8.163         41    5
# 3                4              4     5.0    58      +17.181         58    7
# 4                5              5     4.0    58      +18.014         43    1
# ...            ...            ...     ...   ...          ...        ...  ...
# 26073           14             14     0.0    44    +1:36.184         35    3
# 26074           15             15     0.0    44    +1:41.754         27   14
# 26075           16             16     0.0    44    +1:43.071         25   15
# 26076           17             17     0.0    44    +1:44.476         37    9
# 26077           18             18     0.0    44    +1:50.450         26    4
#
#       fastestLapTime fastestLapSpeed  statusId  fastestLapTime_seconds
# 0           1:27.452         218.300         1                  87.452
# 1           1:27.739         217.586         1                  87.739
# 2           1:28.090         216.719         1                  88.090
# 3           1:28.603         215.464         1                  88.603
# 4           1:27.418         218.385         1                  87.418
# ...              ...             ...       ...                     ...
# 26073       1:49.841         229.553         1                 109.841
# 26074       1:50.993         227.171         1                 110.993
# 26075       1:50.994         227.169         1                 110.994
# 26076       1:50.486         228.213         1                 110.486
# 26077       1:49.907         229.415         1                 109.907
#
# [15207 rows x 18 columns]

# %%
results = results.dropna(subset=['fastestLapTime_seconds'])

# %%
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26073     26079    1110       848              3     23    15       14
# 26074     26080    1110       825            210     20    16       15
# 26075     26081    1110       817            213      3    19       16
# 26076     26082    1110       858              3      2    18       17
# 26077     26083    1110       807            210     27     0       18
#
#       positionText  positionOrder  points  laps         time fastestLap rank  \
# 0                1              1    10.0    58  1:34:50.616         39    2
# 1                2              2     8.0    58       +5.478         41    3
# 2                3              3     6.0    58       +8.163         41    5
# 3                4              4     5.0    58      +17.181         58    7
# 4                5              5     4.0    58      +18.014         43    1
# ...            ...            ...     ...   ...          ...        ...  ...
# 26073           14             14     0.0    44    +1:36.184         35    3
# 26074           15             15     0.0    44    +1:41.754         27   14
# 26075           16             16     0.0    44    +1:43.071         25   15
# 26076           17             17     0.0    44    +1:44.476         37    9
# 26077           18             18     0.0    44    +1:50.450         26    4
#
#       fastestLapTime fastestLapSpeed  statusId  fastestLapTime_seconds
# 0           1:27.452         218.300         1                  87.452
# 1           1:27.739         217.586         1                  87.739
# 2           1:28.090         216.719         1                  88.090
# 3           1:28.603         215.464         1                  88.603
# 4           1:27.418         218.385         1                  87.418
# ...              ...             ...       ...                     ...
# 26073       1:49.841         229.553         1                 109.841
# 26074       1:50.993         227.171         1                 110.993
# 26075       1:50.994         227.169         1                 110.994
# 26076       1:50.486         228.213         1                 110.486
# 26077       1:49.907         229.415         1                 109.907
#
# [6438 rows x 18 columns]

# %%
results.to_csv('cleanedResults.csv', index = False)

# %% [markdown]
# # Correlation between dataset

# %%
## we will start our preliminary analysis by finding the correlation bewteen dataset
## the first step is to join certain dataset by their primary key to get a new result dataset
mergedResults = pd.merge(results, races, left_on = 'raceId', right_index = True, how = 'left')
mergedResults = pd.merge(mergedResults, circuits, left_on = 'circuitId', right_index = True, how = 'left')
mergedResults = pd.merge(mergedResults, constructors, left_on = 'constructorId', right_index = True, how = 'left')
mergedResults = pd.merge(mergedResults, drivers, left_on = 'driverId', right_index = True, how = 'left')
mergedResults
# Out:
#        resultId  raceId_x  driverId_x  constructorId_x number  grid position  \
# 0             1        18           1                1     22     1        1
# 1             2        18           2                2      3     5        2
# 2             3        18           3                3      7     7        3
# 3             4        18           4                4      5    11        4
# 4             5        18           5                1     23     3        5
# ...         ...       ...         ...              ...    ...   ...      ...
# 26075     26081      1110         817              213      3    19       16
# 26076     26082      1110         858                3      2    18       17
# 26077     26083      1110         807              210     27     0       18
# 26078     26084      1110         832                6     55     4       \N
# 26079     26085      1110         857                1     81     5       \N
#
#       positionText  positionOrder  points  ...      lat      lng  alt  \
# 0                1              1    10.0  ...  26.0325  50.5106    7
# 1                2              2     8.0  ...  26.0325  50.5106    7
# 2                3              3     6.0  ...  26.0325  50.5106    7
# 3                4              4     5.0  ...  26.0325  50.5106    7
# 4                5              5     4.0  ...  26.0325  50.5106    7
# ...            ...            ...     ...  ...      ...      ...  ...
# 26075           16             16     0.0  ...      NaN      NaN  NaN
# 26076           17             17     0.0  ...      NaN      NaN  NaN
# 26077           18             18     0.0  ...      NaN      NaN  NaN
# 26078            R             19     0.0  ...      NaN      NaN  NaN
# 26079            R             20     0.0  ...      NaN      NaN  NaN
#
#       constructorId_y constructorRef constructorName  constructorNationality  \
# 0                 2.0     bmw_sauber      BMW Sauber                  German
# 1                 3.0       williams        Williams                 British
# 2                 4.0        renault         Renault                  French
# 3                 5.0     toro_rosso      Toro Rosso                 Italian
# 4                 2.0     bmw_sauber      BMW Sauber                  German
# ...               ...            ...             ...                     ...
# 26075             NaN            NaN             NaN                     NaN
# 26076             4.0        renault         Renault                  French
# 26077           214.0         alpine  Alpine F1 Team                  French
# 26078             7.0         toyota          Toyota                Japanese
# 26079             2.0     bmw_sauber      BMW Sauber                  German
#
#        driverId_y  driverNationality         driverName
# 0             2.0             German      Nick Heidfeld
# 1             3.0             German       Nico Rosberg
# 2             4.0            Spanish    Fernando Alonso
# 3             5.0            Finnish  Heikki Kovalainen
# 4             6.0           Japanese    Kazuki Nakajima
# ...           ...                ...                ...
# 26075       818.0             French   Jean-Éric Vergne
# 26076         NaN                NaN                NaN
# 26077       807.0             German    Nico Hülkenberg
# 26078       833.0            Spanish      Roberto Merhi
# 26079         NaN                NaN                NaN
#
# [26080 rows x 39 columns]

# %%
mergedPitStops = pd.merge(pitStops,races, left_on = 'raceId', right_index = True, how = 'left')
mergedPitStops = pd.merge(mergedPitStops,circuits, left_on = 'circuitId', right_index = True, how = 'left')
mergedPitStops = pd.merge(mergedPitStops, mergedResults[['raceId_x', 'driverId_x', 'driverName', 'constructorId_x', 'constructorName']], left_on = ['raceId_x', 'driverId'], right_on = ['raceId_x', 'driverId_x'])
mergedPitStops
# Out:
#        raceId_x  driverId  stop  lap   pitTime duration  seconds  raceId_y  \
# 0           841       153     1    1  17:05:23   26.898   26.898     843.0
# 1           841       153     2   17  17:31:06   24.463   24.463     843.0
# 2           841       153     3   35  17:59:45   26.348   26.348     843.0
# 3           841        30     1    1  17:05:52   25.021   25.021     843.0
# 4           841        30     2   17  17:32:08   23.988   23.988     843.0
# ...         ...       ...   ...  ...       ...      ...      ...       ...
# 10084      1110       830     1   14  15:30:04   22.887   22.887       NaN
# 10085      1110       830     2   30  16:00:16   23.012   23.012       NaN
# 10086      1110       840     1   20  15:42:12   25.397   25.397       NaN
# 10087      1110       847     1   22  15:46:00   23.837   23.837       NaN
# 10088      1110       842     1   23  15:48:00   25.664   25.664       NaN
#
#          year  round  ...                 circuitName circuitLocation  \
# 0      2011.0    3.0  ...  Autódromo José Carlos Pace       São Paulo
# 1      2011.0    3.0  ...  Autódromo José Carlos Pace       São Paulo
# 2      2011.0    3.0  ...  Autódromo José Carlos Pace       São Paulo
# 3      2011.0    3.0  ...  Autódromo José Carlos Pace       São Paulo
# 4      2011.0    3.0  ...  Autódromo José Carlos Pace       São Paulo
# ...       ...    ...  ...                         ...             ...
# 10084     NaN    NaN  ...                         NaN             NaN
# 10085     NaN    NaN  ...                         NaN             NaN
# 10086     NaN    NaN  ...                         NaN             NaN
# 10087     NaN    NaN  ...                         NaN             NaN
# 10088     NaN    NaN  ...                         NaN             NaN
#
#       circuitCountry      lat      lng  alt driverId_x          driverName  \
# 0             Brazil -23.7036 -46.6997  785        153     Romain Grosjean
# 1             Brazil -23.7036 -46.6997  785        153     Romain Grosjean
# 2             Brazil -23.7036 -46.6997  785        153     Romain Grosjean
# 3             Brazil -23.7036 -46.6997  785         30  Juan Pablo Montoya
# 4             Brazil -23.7036 -46.6997  785         30  Juan Pablo Montoya
# ...              ...      ...      ...  ...        ...                 ...
# 10084            NaN      NaN      NaN  NaN        830         Felipe Nasr
# 10085            NaN      NaN      NaN  NaN        830         Felipe Nasr
# 10086            NaN      NaN      NaN  NaN        840  Antonio Giovinazzi
# 10087            NaN      NaN      NaN  NaN        847     Nicholas Latifi
# 10088            NaN      NaN      NaN  NaN        842     Charles Leclerc
#
#       constructorId_x  constructorName
# 0                   5          Ferrari
# 1                   5          Ferrari
# 2                   5          Ferrari
# 3                 131              HWM
# 4                 131              HWM
# ...               ...              ...
# 10084               9      Force India
# 10085               9      Force India
# 10086             117            Moore
# 10087             131              HWM
# 10088             214              NaN
#
# [10089 rows x 26 columns]

# %%
raceResults = pd.merge(mergedResults, mergedPitStops.groupby(by = ['raceId_x', 'raceName', 'constructorName', 'driverId', 'driverName']).sum(), left_on = ['raceId_x', 'driverId_x'], right_on = ['raceId_x', 'driverId'], how = 'left')
raceResults
# Out:
# /var/folders/j9/cbm31jzn08z95c3hz67rzjyc0000gn/T/ipykernel_67026/2923723585.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   raceResults = pd.merge(mergedResults, mergedPitStops.groupby(by = ['raceId_x', 'raceName', 'constructorName', 'driverId', 'driverName']).sum(), left_on = ['raceId_x', 'driverId_x'], right_on = ['raceId_x', 'driverId'], how = 'left')
#        resultId  raceId_x  driverId_x_x  constructorId_x_x number  grid  \
# 0             1        18             1                  1     22     1
# 1             2        18             2                  2      3     5
# 2             3        18             3                  3      7     7
# 3             4        18             4                  4      5    11
# 4             5        18             5                  1     23     3
# ...         ...       ...           ...                ...    ...   ...
# 26075     26081      1110           817                213      3    19
# 26076     26082      1110           858                  3      2    18
# 26077     26083      1110           807                210     27     0
# 26078     26084      1110           832                  6     55     4
# 26079     26085      1110           857                  1     81     5
#
#       position positionText  positionOrder  points  ...  seconds raceId_y_y  \
# 0            1            1              1    10.0  ...      NaN        NaN
# 1            2            2              2     8.0  ...      NaN        NaN
# 2            3            3              3     6.0  ...      NaN        NaN
# 3            4            4              4     5.0  ...      NaN        NaN
# 4            5            5              5     4.0  ...      NaN        NaN
# ...        ...          ...            ...     ...  ...      ...        ...
# 26075       16           16             16     0.0  ...      NaN        NaN
# 26076       17           17             17     0.0  ...      NaN        NaN
# 26077       18           18             18     0.0  ...      NaN        NaN
# 26078       \N            R             19     0.0  ...      NaN        NaN
# 26079       \N            R             20     0.0  ...      NaN        NaN
#
#       year_y round_y circuitId_x_y circuitId_y_y  lat_y  lng_y  driverId_x_y  \
# 0        NaN     NaN           NaN           NaN    NaN    NaN           NaN
# 1        NaN     NaN           NaN           NaN    NaN    NaN           NaN
# 2        NaN     NaN           NaN           NaN    NaN    NaN           NaN
# 3        NaN     NaN           NaN           NaN    NaN    NaN           NaN
# 4        NaN     NaN           NaN           NaN    NaN    NaN           NaN
# ...      ...     ...           ...           ...    ...    ...           ...
# 26075    NaN     NaN           NaN           NaN    NaN    NaN           NaN
# 26076    NaN     NaN           NaN           NaN    NaN    NaN           NaN
# 26077    NaN     NaN           NaN           NaN    NaN    NaN           NaN
# 26078    NaN     NaN           NaN           NaN    NaN    NaN           NaN
# 26079    NaN     NaN           NaN           NaN    NaN    NaN           NaN
#
#        constructorId_x_y
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 26075                NaN
# 26076                NaN
# 26077                NaN
# 26078                NaN
# 26079                NaN
#
# [26080 rows x 51 columns]

# %% [markdown]
# #### We have some variables naming issue that lots of variables are sharing the same variable name in different dataset when we try to merge datasets in the first time. Therefore, renaming variables in each dataset is necessary. The above code is actually the second time mergeing and since code of merging dataset are the same, only the second time merging process are displayed.

# %%
fig = px.line(mergedPitStops[mergedPitStops['seconds'] < 50].groupby(by = ['year', 'constructorName']).mean(numeric_only=True).reset_index(),
                 x = 'year',
                 y = 'seconds',
                 color = 'constructorName'
                )
fig.update_layout(
    title_text='Average Pit Stop Times by Constructor',
)
fig.show()

# %%
fig = px.box(mergedPitStops[mergedPitStops['seconds'] < 50].groupby(by = ['raceId_x', 'raceName', 'date', 'constructorName']).mean(numeric_only=True).reset_index().sort_values(by = 'seconds', ascending = True),
                 x = 'constructorName',
                 y = 'seconds',
                 color = 'constructorName'
                )
fig.update_layout(
    title_text='Pit Stop Durations by Constructor from 2011 to date',
)
fig.show()

# %% [markdown]
# # Outlier

# %%
Q1 = mergedResults.quantile(0.25)
Q3 = mergedResults.quantile(0.25)
IQR = Q3 - Q1
mergedResults[~((mergedResults < (Q1 - 1.5*IQR))| (mergedResults > (Q3 + 1.5*IQR))).any(axis = 1)]
mergedResults
# Out:
# /var/folders/j9/cbm31jzn08z95c3hz67rzjyc0000gn/T/ipykernel_67026/1743655405.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# /var/folders/j9/cbm31jzn08z95c3hz67rzjyc0000gn/T/ipykernel_67026/1743655405.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#
# /var/folders/j9/cbm31jzn08z95c3hz67rzjyc0000gn/T/ipykernel_67026/1743655405.py:4: FutureWarning:
#
# Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#        resultId  raceId_x  driverId_x  constructorId_x number  grid position  \
# 0             1        18           1                1     22     1        1
# 1             2        18           2                2      3     5        2
# 2             3        18           3                3      7     7        3
# 3             4        18           4                4      5    11        4
# 4             5        18           5                1     23     3        5
# ...         ...       ...         ...              ...    ...   ...      ...
# 26075     26081      1110         817              213      3    19       16
# 26076     26082      1110         858                3      2    18       17
# 26077     26083      1110         807              210     27     0       18
# 26078     26084      1110         832                6     55     4       \N
# 26079     26085      1110         857                1     81     5       \N
#
#       positionText  positionOrder  points  ...      lat      lng  alt  \
# 0                1              1    10.0  ...  26.0325  50.5106    7
# 1                2              2     8.0  ...  26.0325  50.5106    7
# 2                3              3     6.0  ...  26.0325  50.5106    7
# 3                4              4     5.0  ...  26.0325  50.5106    7
# 4                5              5     4.0  ...  26.0325  50.5106    7
# ...            ...            ...     ...  ...      ...      ...  ...
# 26075           16             16     0.0  ...      NaN      NaN  NaN
# 26076           17             17     0.0  ...      NaN      NaN  NaN
# 26077           18             18     0.0  ...      NaN      NaN  NaN
# 26078            R             19     0.0  ...      NaN      NaN  NaN
# 26079            R             20     0.0  ...      NaN      NaN  NaN
#
#       constructorId_y constructorRef constructorName  constructorNationality  \
# 0                 2.0     bmw_sauber      BMW Sauber                  German
# 1                 3.0       williams        Williams                 British
# 2                 4.0        renault         Renault                  French
# 3                 5.0     toro_rosso      Toro Rosso                 Italian
# 4                 2.0     bmw_sauber      BMW Sauber                  German
# ...               ...            ...             ...                     ...
# 26075             NaN            NaN             NaN                     NaN
# 26076             4.0        renault         Renault                  French
# 26077           214.0         alpine  Alpine F1 Team                  French
# 26078             7.0         toyota          Toyota                Japanese
# 26079             2.0     bmw_sauber      BMW Sauber                  German
#
#        driverId_y  driverNationality         driverName
# 0             2.0             German      Nick Heidfeld
# 1             3.0             German       Nico Rosberg
# 2             4.0            Spanish    Fernando Alonso
# 3             5.0            Finnish  Heikki Kovalainen
# 4             6.0           Japanese    Kazuki Nakajima
# ...           ...                ...                ...
# 26075       818.0             French   Jean-Éric Vergne
# 26076         NaN                NaN                NaN
# 26077       807.0             German    Nico Hülkenberg
# 26078       833.0            Spanish      Roberto Merhi
# 26079         NaN                NaN                NaN
#
# [26080 rows x 39 columns]

# %% [markdown]
# #### there are no obvious outlier detected since no rows was removed

# %% [markdown]
# # Hypothesis Refination
#
# ## We car observe that there are some differences between every constructor's pit stop time, however, those differences are within the range of 1 to 2 seconds which is quite insignificant even in the formula 1 race since there are many uncertainty in the race and any of those uncertainty could cause error more than 2 seconds
#
# ## Therefore, hypothesis of this project should divert to will the pit stop time differences have the effect of determine the winner of one race in the following project.

# %%
mergedResults.to_csv('mergedResults.csv', index = False)
